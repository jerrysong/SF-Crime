# %% [markdown]
# First attempt at pulling data from Kaggle and recoding categorical variables of interest into dummy variables.

# %%
# %matplotlib inline

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data Structure
import numpy as np
import scipy as sp
import pandas as pd

# Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture as GMM

# Others
from datetime import datetime
import zipfile
import os.path
# Out:
# /anaconda/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# # Import Data

# %%
# Load the data and examine it
if os.path.isfile('./train.csv'):
    train_data = pd.read_csv('./train.csv')
else:
    z = zipfile.ZipFile('./train.csv.zip')
    train_data = pd.read_csv(z.open('train.csv'))

# %%
if os.path.isfile('./test.csv'):
    test_data = pd.read_csv('./test.csv')
else:
    z = zipfile.ZipFile('./test.csv.zip')
    test_data = pd.read_csv(z.open('test.csv'))

# %% [markdown]
# # Data Cleansing

# %%
print('Before data cleansing, the train data contain %d samples, the test data contain %d samples.' % \
      (train_data.shape[0], test_data.shape[0]))

# Drop samples containing null fields
train_data = train_data.dropna()
test_data = test_data.dropna()

# The boundaries of valid longitude and latitude
lon_lat_box = (-122.5247, -122.3366, 37.699, 37.8299)

# Drop samples containing invalide longitude and latitude
train_data = train_data[train_data.X > lon_lat_box[0]]
train_data = train_data[train_data.X < lon_lat_box[1]]
train_data = train_data[train_data.Y > lon_lat_box[2]]
train_data = train_data[train_data.Y < lon_lat_box[3]]

test_data = test_data[test_data.X > lon_lat_box[0]]
test_data = test_data[test_data.X < lon_lat_box[1]]
test_data = test_data[test_data.Y > lon_lat_box[2]]
test_data = test_data[test_data.Y < lon_lat_box[3]]

print('After data cleansing, the train data contain %d samples, the test data contain %d samples.' % \
      (train_data.shape[0], test_data.shape[0]))
# Out:
# Before data cleansing, the train data contain 877982 samples, the test data contain 884186 samples.
# After data cleansing, the train data contain 877982 samples, the test data contain 884186 samples.

# %%
# Show all available crime lables.
print(train_data['Category'].value_counts())

# Show the percentage of the mode in all data. If the prediction of the model is worse than always predicting the mode,
# then we should always predict the mode in the baseline establishment.
print('The percentage of the LARCENY/THEFT is: ', train_data['Category'].value_counts()[0] * 1.0 / train_data.shape[0])
# Out:
# LARCENY/THEFT                  174885
# OTHER OFFENSES                 126165
# NON-CRIMINAL                    92300
# ASSAULT                         76872
# DRUG/NARCOTIC                   53971
# VEHICLE THEFT                   53772
# VANDALISM                       44724
# WARRANTS                        42206
# BURGLARY                        36754
# SUSPICIOUS OCC                  31412
# MISSING PERSON                  25989
# ROBBERY                         22999
# FRAUD                           16679
# FORGERY/COUNTERFEITING          10609
# SECONDARY CODES                  9985
# WEAPON LAWS                      8555
# PROSTITUTION                     7484
# TRESPASS                         7325
# STOLEN PROPERTY                  4539
# SEX OFFENSES FORCIBLE            4387
# DISORDERLY CONDUCT               4318
# DRUNKENNESS                      4280
# RECOVERED VEHICLE                3138
# KIDNAPPING                       2341
# DRIVING UNDER THE INFLUENCE      2268
# RUNAWAY                          1946
# LIQUOR LAWS                      1903
# ARSON                            1513
# LOITERING                        1225
# EMBEZZLEMENT                     1166
# SUICIDE                           508
# FAMILY OFFENSES                   491
# BAD CHECKS                        406
# BRIBERY                           289
# EXTORTION                         256
# SEX OFFENSES NON FORCIBLE         148
# GAMBLING                          146
# PORNOGRAPHY/OBSCENE MAT            22
# TREA                                6
# Name: Category, dtype: int64
# The percentage of the LARCENY/THEFT is:  0.199189732819

# %%
# Convert the date into a python datetime object.
train_data["Dates"] = pd.to_datetime(train_data["Dates"], format="%Y-%m-%d %H:%M:%S")
test_data["Dates"] = pd.to_datetime(test_data["Dates"], format="%Y-%m-%d %H:%M:%S")

# %%
from sklearn.preprocessing import LabelEncoder

print(train_data.shape, test_data.shape)

#let's back stuff up
# Before we train the models, we need to divide the data into train data and dev data.
train1_data = train_data.copy()

# split to train / dev 
shuffle = np.random.permutation(np.arange(train1_data.shape[0]))
train1_data = train1_data.iloc[shuffle]
train1_labels = train1_data['Category']

train1_data["Hour"] = train_data["Dates"].apply(lambda x: x.hour)

# drop unnecessary stuff
train1_data = train1_data.drop(['Category','Address','Dates','Descript','Resolution'], axis=1)
    

# normalize X and Y
train1_data[['X','Y']] = scale(train1_data[['X','Y']])

# let's create integer values for each categories (akin to as.Factor() in R)
#train1_data['Descript'] = LabelEncoder().fit_transform(train1_data['Descript'])
#train1_data['Resolution'] = LabelEncoder().fit_transform(train1_data['Resolution'])
train1_data['DayOfWeek'] = LabelEncoder().fit_transform(train1_data['DayOfWeek'])
train1_data['PdDistrict'] = LabelEncoder().fit_transform(train1_data['PdDistrict'])

mini_train1_data = train1_data.iloc[:60000]
mini_train1_labels = train1_labels.iloc[:60000]
# Out:
# (877982, 9) (884186, 7)

# %%
# Out:
# <bound method Series.unique of 0                       WARRANTS
# 1                 OTHER OFFENSES
# 2                 OTHER OFFENSES
# 3                  LARCENY/THEFT
# 4                  LARCENY/THEFT
# 5                  LARCENY/THEFT
# 6                  VEHICLE THEFT
# 7                  VEHICLE THEFT
# 8                  LARCENY/THEFT
# 9                  LARCENY/THEFT
# 10                 LARCENY/THEFT
# 11                OTHER OFFENSES
# 12                     VANDALISM
# 13                 LARCENY/THEFT
# 14                  NON-CRIMINAL
# 15                  NON-CRIMINAL
# 16                       ROBBERY
# 17                       ASSAULT
# 18                OTHER OFFENSES
# 19                  NON-CRIMINAL
# 20                 LARCENY/THEFT
# 21                       ROBBERY
# 22                      WARRANTS
# 23                  NON-CRIMINAL
# 24                 LARCENY/THEFT
# 25                  NON-CRIMINAL
# 26                 LARCENY/THEFT
# 27                 LARCENY/THEFT
# 28                 LARCENY/THEFT
# 29                OTHER OFFENSES
#                    ...
# 878019            OTHER OFFENSES
# 878020            OTHER OFFENSES
# 878021                 VANDALISM
# 878022             VEHICLE THEFT
# 878023             LARCENY/THEFT
# 878024            OTHER OFFENSES
# 878025            OTHER OFFENSES
# 878026                  WARRANTS
# 878027                  WARRANTS
# 878028                   ASSAULT
# 878029            OTHER OFFENSES
# 878030     SEX OFFENSES FORCIBLE
# 878031                   ASSAULT
# 878032            OTHER OFFENSES
# 878033                 VANDALISM
# 878034                  TRESPASS
# 878035                   ASSAULT
# 878036             LARCENY/THEFT
# 878037                 VANDALISM
# 878038                  WARRANTS
# 878039            OTHER OFFENSES
# 878040                   ASSAULT
# 878041            OTHER OFFENSES
# 878042                   ASSAULT
# 878043            OTHER OFFENSES
# 878044                   ROBBERY
# 878045             LARCENY/THEFT
# 878046             LARCENY/THEFT
# 878047                 VANDALISM
# 878048    FORGERY/COUNTERFEITING
# Name: Category, dtype: object>

# %%
pca_mod = PCA()
pca_mod.fit(train1_data)
train1_2d = pca_mod.transform(mini_train1_data)
for crime in train_data["Category"].unique():
    
    positive_indices = np.array(np.where(mini_train1_labels == crime))[0,:]
    negative_indices = np.array(np.where(mini_train1_labels != crime))[0,:]
    
    positive_sample_size = positive_indices.shape[0]
    negative_sample_size = negative_indices.shape[0]
    train1_2d_positive = train1_2d[positive_indices,]
    train1_2d_negative = train1_2d[negative_indices,]
  
    
   

    mini_dev_data = train1_data.iloc[60000:80000]
    mini_dev_labels = train1_labels.iloc[60000:80000]

    
    
    test_2d_data = pca_mod.transform(mini_dev_data)
    positive_indices = np.array(np.where(mini_dev_labels == crime))[0,:]
    negative_indices = np.array(np.where(mini_dev_labels != crime))[0,:]
    test_2d_data_positive = test_2d_data[positive_indices,]
    test_2d_data_negative = test_2d_data[negative_indices,]

    
    print("for crime {0:s}".format(crime))
    print("positive training sample size is {0:d}".format(train1_2d_positive.shape[0]))
      
    print("negative training sample size is {0:d}".format(train1_2d_negative.shape[0]))
      
    print("positive test sample size is {0:d}".format(test_2d_data_positive.shape[0]))
      
    print("negative test sample size is {0:d}".format(test_2d_data_negative.shape[0]))

    components = min(4,min(positive_sample_size,negative_sample_size))
    
    print("GMM components size: {0:d}".format(components))
    gmm_positive = GMM(n_components = components, covariance_type = 'full' )
    gmm_positive.fit(train1_2d_positive)
    gmm_negative = GMM(n_components = components, covariance_type = 'full' )
    gmm_negative.fit(train1_2d_negative)
    log_probas_positive = gmm_positive.score_samples(test_2d_data)
    log_probas_negative = gmm_negative.score_samples(test_2d_data)


    predicted_int_labels = np.greater(log_probas_positive, log_probas_negative).astype(int)
    mini_dev_int_labels = np.array(mini_dev_labels == crime, dtype = int)
    accuracy = np.sum(np.equal(mini_dev_int_labels, predicted_int_labels))/mini_dev_int_labels.shape[0]
    print("The accuracy is for {0:s}: {1:3f}".format(crime, accuracy))
# Out:
# for crime WARRANTS
# positive training sample size is 2904
# negative training sample size is 57096
# positive test sample size is 949
# negative test sample size is 19051
# GMM components size: 4
# The accuracy is for WARRANTS: 0.448950
# for crime OTHER OFFENSES
# positive training sample size is 8721
# negative training sample size is 51279
# positive test sample size is 2927
# negative test sample size is 17073
# GMM components size: 4
# The accuracy is for OTHER OFFENSES: 0.518600
# for crime LARCENY/THEFT
# positive training sample size is 11985
# negative training sample size is 48015
# positive test sample size is 3897
# negative test sample size is 16103
# GMM components size: 4
# The accuracy is for LARCENY/THEFT: 0.545450
# for crime VEHICLE THEFT
# positive training sample size is 3629
# negative training sample size is 56371
# positive test sample size is 1216
# negative test sample size is 18784
# GMM components size: 4
# The accuracy is for VEHICLE THEFT: 0.602900
# for crime VANDALISM
# positive training sample size is 2992
# negative training sample size is 57008
# positive test sample size is 1014
# negative test sample size is 18986
# GMM components size: 4
# The accuracy is for VANDALISM: 0.566650
# for crime NON-CRIMINAL
# positive training sample size is 6296
# negative training sample size is 53704
# positive test sample size is 2165
# negative test sample size is 17835
# GMM components size: 4
# The accuracy is for NON-CRIMINAL: 0.628900
# for crime ROBBERY
# positive training sample size is 1540
# negative training sample size is 58460
# positive test sample size is 537
# negative test sample size is 19463
# GMM components size: 4
# The accuracy is for ROBBERY: 0.455950
# for crime ASSAULT
# positive training sample size is 5267
# negative training sample size is 54733
# positive test sample size is 1757
# negative test sample size is 18243
# GMM components size: 4
# The accuracy is for ASSAULT: 0.357600
# for crime WEAPON LAWS
# positive training sample size is 598
# negative training sample size is 59402
# positive test sample size is 186
# negative test sample size is 19814
# GMM components size: 4
# The accuracy is for WEAPON LAWS: 0.458800
# for crime BURGLARY
# positive training sample size is 2468
# negative training sample size is 57532
# positive test sample size is 852
# negative test sample size is 19148
# GMM components size: 4
# The accuracy is for BURGLARY: 0.581150
# for crime SUSPICIOUS OCC
# positive training sample size is 2126
# negative training sample size is 57874
# positive test sample size is 743
# negative test sample size is 19257
# GMM components size: 4
# The accuracy is for SUSPICIOUS OCC: 0.577100
# for crime DRUNKENNESS
# positive training sample size is 318
# negative training sample size is 59682
# positive test sample size is 85
# negative test sample size is 19915
# GMM components size: 4
# The accuracy is for DRUNKENNESS: 0.712200
# for crime FORGERY/COUNTERFEITING
# positive training sample size is 703
# negative training sample size is 59297
# positive test sample size is 278
# negative test sample size is 19722
# GMM components size: 4
# The accuracy is for FORGERY/COUNTERFEITING: 0.623300
# for crime DRUG/NARCOTIC
# positive training sample size is 3669
# negative training sample size is 56331
# positive test sample size is 1178
# negative test sample size is 18822
# GMM components size: 4
# The accuracy is for DRUG/NARCOTIC: 0.721400
# for crime STOLEN PROPERTY
# positive training sample size is 276
# negative training sample size is 59724
# positive test sample size is 102
# negative test sample size is 19898
# GMM components size: 4
# The accuracy is for STOLEN PROPERTY: 0.573800
# for crime SECONDARY CODES
# positive training sample size is 681
# negative training sample size is 59319
# positive test sample size is 225
# negative test sample size is 19775
# GMM components size: 4
# The accuracy is for SECONDARY CODES: 0.665950
# for crime TRESPASS
# positive training sample size is 504
# negative training sample size is 59496
# positive test sample size is 159
# negative test sample size is 19841
# GMM components size: 4
# The accuracy is for TRESPASS: 0.549650
# for crime MISSING PERSON
# positive training sample size is 1829
# negative training sample size is 58171
# positive test sample size is 563
# negative test sample size is 19437
# GMM components size: 4
# The accuracy is for MISSING PERSON: 0.483650
# for crime FRAUD
# positive training sample size is 1120
# negative training sample size is 58880
# positive test sample size is 361
# negative test sample size is 19639
# GMM components size: 4
# The accuracy is for FRAUD: 0.580100
# for crime KIDNAPPING
# positive training sample size is 163
# negative training sample size is 59837
# positive test sample size is 60
# negative test sample size is 19940
# GMM components size: 4
# The accuracy is for KIDNAPPING: 0.657950
# for crime RUNAWAY
# positive training sample size is 163
# negative training sample size is 59837
# positive test sample size is 44
# negative test sample size is 19956
# GMM components size: 4
# The accuracy is for RUNAWAY: 0.752400
# for crime DRIVING UNDER THE INFLUENCE
# positive training sample size is 148
# negative training sample size is 59852
# positive test sample size is 52
# negative test sample size is 19948
# GMM components size: 4
# The accuracy is for DRIVING UNDER THE INFLUENCE: 0.775200
# for crime SEX OFFENSES FORCIBLE
# positive training sample size is 287
# negative training sample size is 59713
# positive test sample size is 101
# negative test sample size is 19899
# GMM components size: 4
# The accuracy is for SEX OFFENSES FORCIBLE: 0.541050
# for crime PROSTITUTION
# positive training sample size is 483
# negative training sample size is 59517
# positive test sample size is 173
# negative test sample size is 19827
# GMM components size: 4
# The accuracy is for PROSTITUTION: 0.884300
# for crime DISORDERLY CONDUCT
# positive training sample size is 319
# negative training sample size is 59681
# positive test sample size is 118
# negative test sample size is 19882
# GMM components size: 4
# The accuracy is for DISORDERLY CONDUCT: 0.684900
# for crime ARSON
# positive training sample size is 110
# negative training sample size is 59890
# positive test sample size is 44
# negative test sample size is 19956
# GMM components size: 4
# The accuracy is for ARSON: 0.784700
# for crime FAMILY OFFENSES
# positive training sample size is 27
# negative training sample size is 59973
# positive test sample size is 8
# negative test sample size is 19992
# GMM components size: 4
# The accuracy is for FAMILY OFFENSES: 0.916200
# for crime LIQUOR LAWS
# positive training sample size is 118
# negative training sample size is 59882
# positive test sample size is 42
# negative test sample size is 19958
# GMM components size: 4
# The accuracy is for LIQUOR LAWS: 0.810400
# for crime BRIBERY
# positive training sample size is 20
# negative training sample size is 59980
# positive test sample size is 9
# negative test sample size is 19991
# GMM components size: 4
# The accuracy is for BRIBERY: 0.852200
# for crime EMBEZZLEMENT
# positive training sample size is 100
# negative training sample size is 59900
# positive test sample size is 33
# negative test sample size is 19967
# GMM components size: 4
# The accuracy is for EMBEZZLEMENT: 0.795950
# for crime SUICIDE
# positive training sample size is 47
# negative training sample size is 59953
# positive test sample size is 11
# negative test sample size is 19989
# GMM components size: 4
# The accuracy is for SUICIDE: 0.820350
# for crime LOITERING
# positive training sample size is 89
# negative training sample size is 59911
# positive test sample size is 28
# negative test sample size is 19972
# GMM components size: 4
# The accuracy is for LOITERING: 0.797000
# for crime SEX OFFENSES NON FORCIBLE
# positive training sample size is 8
# negative training sample size is 59992
# positive test sample size is 7
# negative test sample size is 19993
# GMM components size: 4
# The accuracy is for SEX OFFENSES NON FORCIBLE: 0.999650
# for crime EXTORTION
# positive training sample size is 15
# negative training sample size is 59985
# positive test sample size is 2
# negative test sample size is 19998
# GMM components size: 4
# The accuracy is for EXTORTION: 0.999350
# for crime GAMBLING
# positive training sample size is 12
# negative training sample size is 59988
# positive test sample size is 2
# negative test sample size is 19998
# GMM components size: 4
# The accuracy is for GAMBLING: 0.832350
# for crime BAD CHECKS
# positive training sample size is 32
# negative training sample size is 59968
# positive test sample size is 12
# negative test sample size is 19988
# GMM components size: 4
# The accuracy is for BAD CHECKS: 0.839650
# for crime TREA
# positive training sample size is 1
# negative training sample size is 59999
# positive test sample size is 0
# negative test sample size is 20000
# GMM components size: 1
# The accuracy is for TREA: 1.000000
# for crime RECOVERED VEHICLE
# positive training sample size is 231
# negative training sample size is 59769
# positive test sample size is 59
# negative test sample size is 19941
# GMM components size: 4
# The accuracy is for RECOVERED VEHICLE: 0.714050
# for crime PORNOGRAPHY/OBSCENE MAT
# positive training sample size is 1
# negative training sample size is 59999
# positive test sample size is 1
# negative test sample size is 19999
# GMM components size: 1
# The accuracy is for PORNOGRAPHY/OBSCENE MAT: 0.999900
