# %% [markdown]
# First attempt at pulling data from Kaggle and recoding categorical variables of interest into dummy variables.

# %%
# %matplotlib inline

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data Structure
import numpy as np
import scipy as sp
import pandas as pd

# Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture as GMM

# Others
from datetime import datetime
import zipfile
import os.path
# Out:
# /anaconda/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# # Import Data

# %%
# Load the data and examine it
if os.path.isfile('./train.csv'):
    train_data = pd.read_csv('./train.csv')
else:
    z = zipfile.ZipFile('./train.csv.zip')
    train_data = pd.read_csv(z.open('train.csv'))

# %%
if os.path.isfile('./test.csv'):
    test_data = pd.read_csv('./test.csv')
else:
    z = zipfile.ZipFile('./test.csv.zip')
    test_data = pd.read_csv(z.open('test.csv'))

# %% [markdown]
# # Data Cleansing

# %%
print('Before data cleansing, the train data contain %d samples, the test data contain %d samples.' % \
      (train_data.shape[0], test_data.shape[0]))

# Drop samples containing null fields
train_data = train_data.dropna()
test_data = test_data.dropna()

# The boundaries of valid longitude and latitude
lon_lat_box = (-122.5247, -122.3366, 37.699, 37.8299)

# Drop samples containing invalide longitude and latitude
train_data = train_data[train_data.X > lon_lat_box[0]]
train_data = train_data[train_data.X < lon_lat_box[1]]
train_data = train_data[train_data.Y > lon_lat_box[2]]
train_data = train_data[train_data.Y < lon_lat_box[3]]

test_data = test_data[test_data.X > lon_lat_box[0]]
test_data = test_data[test_data.X < lon_lat_box[1]]
test_data = test_data[test_data.Y > lon_lat_box[2]]
test_data = test_data[test_data.Y < lon_lat_box[3]]

print('After data cleansing, the train data contain %d samples, the test data contain %d samples.' % \
      (train_data.shape[0], test_data.shape[0]))
# Out:
# Before data cleansing, the train data contain 877982 samples, the test data contain 884186 samples.
# After data cleansing, the train data contain 877982 samples, the test data contain 884186 samples.

# %%
# Show all available crime lables.
print(train_data['Category'].value_counts())

# Show the percentage of the mode in all data. If the prediction of the model is worse than always predicting the mode,
# then we should always predict the mode in the baseline establishment.
print('The percentage of the LARCENY/THEFT is: ', train_data['Category'].value_counts()[0] * 1.0 / train_data.shape[0])
# Out:
# LARCENY/THEFT                  174885
# OTHER OFFENSES                 126165
# NON-CRIMINAL                    92300
# ASSAULT                         76872
# DRUG/NARCOTIC                   53971
# VEHICLE THEFT                   53772
# VANDALISM                       44724
# WARRANTS                        42206
# BURGLARY                        36754
# SUSPICIOUS OCC                  31412
# MISSING PERSON                  25989
# ROBBERY                         22999
# FRAUD                           16679
# FORGERY/COUNTERFEITING          10609
# SECONDARY CODES                  9985
# WEAPON LAWS                      8555
# PROSTITUTION                     7484
# TRESPASS                         7325
# STOLEN PROPERTY                  4539
# SEX OFFENSES FORCIBLE            4387
# DISORDERLY CONDUCT               4318
# DRUNKENNESS                      4280
# RECOVERED VEHICLE                3138
# KIDNAPPING                       2341
# DRIVING UNDER THE INFLUENCE      2268
# RUNAWAY                          1946
# LIQUOR LAWS                      1903
# ARSON                            1513
# LOITERING                        1225
# EMBEZZLEMENT                     1166
# SUICIDE                           508
# FAMILY OFFENSES                   491
# BAD CHECKS                        406
# BRIBERY                           289
# EXTORTION                         256
# SEX OFFENSES NON FORCIBLE         148
# GAMBLING                          146
# PORNOGRAPHY/OBSCENE MAT            22
# TREA                                6
# Name: Category, dtype: int64
# The percentage of the LARCENY/THEFT is:  0.199189732819

# %%
# Convert the date into a python datetime object.
train_data["Dates"] = pd.to_datetime(train_data["Dates"], format="%Y-%m-%d %H:%M:%S")
test_data["Dates"] = pd.to_datetime(test_data["Dates"], format="%Y-%m-%d %H:%M:%S")

# %%
from sklearn.preprocessing import LabelEncoder

print(train_data.shape, test_data.shape)

#let's back stuff up
# Before we train the models, we need to divide the data into train data and dev data.
train1_data = train_data.copy()

# split to train / dev 
shuffle = np.random.permutation(np.arange(train1_data.shape[0]))
train1_data = train1_data.iloc[shuffle]
train1_labels = train1_data['Category']

train1_data["Hour"] = train_data["Dates"].apply(lambda x: x.hour)

# drop unnecessary stuff
train1_data = train1_data.drop(['Category','Address','Dates','Descript','Resolution'], axis=1)
    

# normalize X and Y
train1_data[['X','Y']] = scale(train1_data[['X','Y']])

# let's create integer values for each categories (akin to as.Factor() in R)
#train1_data['Descript'] = LabelEncoder().fit_transform(train1_data['Descript'])
#train1_data['Resolution'] = LabelEncoder().fit_transform(train1_data['Resolution'])
train1_data['DayOfWeek'] = LabelEncoder().fit_transform(train1_data['DayOfWeek'])
train1_data['PdDistrict'] = LabelEncoder().fit_transform(train1_data['PdDistrict'])

mini_train1_data = train1_data.iloc[:40000]
mini_train1_labels = train1_labels.iloc[:40000]
# Out:
# (877982, 9) (884186, 7)

# %%
pca_mod = PCA()
pca_mod.fit(train1_data)
train1_2d = pca_mod.transform(mini_train1_data)
print(train_data['Category'].unique)
# Out:
# <bound method Series.unique of 0                       WARRANTS
# 1                 OTHER OFFENSES
# 2                 OTHER OFFENSES
# 3                  LARCENY/THEFT
# 4                  LARCENY/THEFT
# 5                  LARCENY/THEFT
# 6                  VEHICLE THEFT
# 7                  VEHICLE THEFT
# 8                  LARCENY/THEFT
# 9                  LARCENY/THEFT
# 10                 LARCENY/THEFT
# 11                OTHER OFFENSES
# 12                     VANDALISM
# 13                 LARCENY/THEFT
# 14                  NON-CRIMINAL
# 15                  NON-CRIMINAL
# 16                       ROBBERY
# 17                       ASSAULT
# 18                OTHER OFFENSES
# 19                  NON-CRIMINAL
# 20                 LARCENY/THEFT
# 21                       ROBBERY
# 22                      WARRANTS
# 23                  NON-CRIMINAL
# 24                 LARCENY/THEFT
# 25                  NON-CRIMINAL
# 26                 LARCENY/THEFT
# 27                 LARCENY/THEFT
# 28                 LARCENY/THEFT
# 29                OTHER OFFENSES
#                    ...
# 878019            OTHER OFFENSES
# 878020            OTHER OFFENSES
# 878021                 VANDALISM
# 878022             VEHICLE THEFT
# 878023             LARCENY/THEFT
# 878024            OTHER OFFENSES
# 878025            OTHER OFFENSES
# 878026                  WARRANTS
# 878027                  WARRANTS
# 878028                   ASSAULT
# 878029            OTHER OFFENSES
# 878030     SEX OFFENSES FORCIBLE
# 878031                   ASSAULT
# 878032            OTHER OFFENSES
# 878033                 VANDALISM
# 878034                  TRESPASS
# 878035                   ASSAULT
# 878036             LARCENY/THEFT
# 878037                 VANDALISM
# 878038                  WARRANTS
# 878039            OTHER OFFENSES
# 878040                   ASSAULT
# 878041            OTHER OFFENSES
# 878042                   ASSAULT
# 878043            OTHER OFFENSES
# 878044                   ROBBERY
# 878045             LARCENY/THEFT
# 878046             LARCENY/THEFT
# 878047                 VANDALISM
# 878048    FORGERY/COUNTERFEITING
# Name: Category, dtype: object>

# %%
for crime in train_data["Category"].unique():
    positive_indices = np.array(np.where(mini_train1_labels == crime))[0,:]
    train1_2d_positive = train1_2d[positive_indices,]
  

    # negative (no LARCENY nor THEFT) clusters
    negative_indices = np.array(np.where(mini_train1_labels != crime))[0,:]
    train1_2d_negative = train1_2d[negative_indices,]

    mini_dev_data = train1_data.iloc[40000:50000]
    mini_dev_labels = train1_labels.iloc[40000:50000]

    
    
    test_2d_data = pca_mod.transform(mini_dev_data)
    # positive clusters 
    positive_indices = np.array(np.where(mini_dev_labels == crime))[0,:]
    test_2d_data_positive = test_2d_data[positive_indices,]

    # negative  clusters
    negative_indices = np.array(np.where(mini_dev_labels != crime))[0,:]
    test_2d_data_negative = test_2d_data[negative_indices,]

    
    print("for crime {0:s}".format(crime))
    print("positive training sample size is {0:d}".format(train1_2d_positive.shape[0]))
      
    print("negative training sample size is {0:d}".format(train1_2d_negative.shape[0]))
      
    print("positive test sample size is {0:d}".format(test_2d_data_positive.shape[0]))
      
    print("negative test sample size is {0:d}".format(test_2d_data_negative.shape[0]))

    gmm_positive = GMM(n_components = 4, covariance_type = 'full' )
    gmm_positive.fit(train1_2d_positive)
    gmm_negative = GMM(n_components = 4, covariance_type = 'full' )
    gmm_negative.fit(train1_2d_negative)
    log_probas_positive = gmm_positive.score_samples(test_2d_data)
    log_probas_negative = gmm_negative.score_samples(test_2d_data)


    predicted_int_labels = np.greater(log_probas_positive, log_probas_negative).astype(int)
    mini_dev_int_labels = np.array(mini_dev_labels == crime, dtype = int)
    accuracy = np.sum(np.equal(mini_dev_int_labels, predicted_int_labels))/mini_dev_int_labels.shape[0]
    print("The accuracy is for {0:s}: {1:3f}".format(crime, accuracy))
# Out:
# for crime WARRANTS
# positive training sample size is 1979
# negative training sample size is 38021
# positive test sample size is 462
# negative test sample size is 9538
# The accuracy is for WARRANTS: 0.642400
# for crime OTHER OFFENSES
# positive training sample size is 5744
# negative training sample size is 34256
# positive test sample size is 1436
# negative test sample size is 8564
# The accuracy is for OTHER OFFENSES: 0.462300
# for crime LARCENY/THEFT
# positive training sample size is 8001
# negative training sample size is 31999
# positive test sample size is 2005
# negative test sample size is 7995
# The accuracy is for LARCENY/THEFT: 0.582200
# for crime VEHICLE THEFT
# positive training sample size is 2436
# negative training sample size is 37564
# positive test sample size is 587
# negative test sample size is 9413
# The accuracy is for VEHICLE THEFT: 0.604500
# for crime VANDALISM
# positive training sample size is 2043
# negative training sample size is 37957
# positive test sample size is 509
# negative test sample size is 9491
# The accuracy is for VANDALISM: 0.567400
# for crime NON-CRIMINAL
# positive training sample size is 4201
# negative training sample size is 35799
# positive test sample size is 1093
# negative test sample size is 8907
# The accuracy is for NON-CRIMINAL: 0.547200
# for crime ROBBERY
# positive training sample size is 1011
# negative training sample size is 38989
# positive test sample size is 246
# negative test sample size is 9754
# The accuracy is for ROBBERY: 0.578200
# for crime ASSAULT
# positive training sample size is 3455
# negative training sample size is 36545
# positive test sample size is 893
# negative test sample size is 9107
# The accuracy is for ASSAULT: 0.620800
# for crime WEAPON LAWS
# positive training sample size is 357
# negative training sample size is 39643
# positive test sample size is 103
# negative test sample size is 9897
# The accuracy is for WEAPON LAWS: 0.666400
# for crime BURGLARY
# positive training sample size is 1741
# negative training sample size is 38259
# positive test sample size is 397
# negative test sample size is 9603
# The accuracy is for BURGLARY: 0.481800
# for crime SUSPICIOUS OCC
# positive training sample size is 1378
# negative training sample size is 38622
# positive test sample size is 368
# negative test sample size is 9632
# The accuracy is for SUSPICIOUS OCC: 0.589700
# for crime DRUNKENNESS
# positive training sample size is 205
# negative training sample size is 39795
# positive test sample size is 45
# negative test sample size is 9955
# The accuracy is for DRUNKENNESS: 0.768700
# for crime FORGERY/COUNTERFEITING
# positive training sample size is 438
# negative training sample size is 39562
# positive test sample size is 143
# negative test sample size is 9857
# The accuracy is for FORGERY/COUNTERFEITING: 0.612700
# for crime DRUG/NARCOTIC
# positive training sample size is 2482
# negative training sample size is 37518
# positive test sample size is 617
# negative test sample size is 9383
# The accuracy is for DRUG/NARCOTIC: 0.590400
# for crime STOLEN PROPERTY
# positive training sample size is 213
# negative training sample size is 39787
# positive test sample size is 66
# negative test sample size is 9934
# The accuracy is for STOLEN PROPERTY: 0.682400
# for crime SECONDARY CODES
# positive training sample size is 468
# negative training sample size is 39532
# positive test sample size is 98
# negative test sample size is 9902
# The accuracy is for SECONDARY CODES: 0.555600
# for crime TRESPASS
# positive training sample size is 324
# negative training sample size is 39676
# positive test sample size is 86
# negative test sample size is 9914
# The accuracy is for TRESPASS: 0.553600
# for crime MISSING PERSON
# positive training sample size is 1224
# negative training sample size is 38776
# positive test sample size is 281
# negative test sample size is 9719
# The accuracy is for MISSING PERSON: 0.621300
# for crime FRAUD
# positive training sample size is 758
# negative training sample size is 39242
# positive test sample size is 193
# negative test sample size is 9807
# The accuracy is for FRAUD: 0.562000
# for crime KIDNAPPING
# positive training sample size is 109
# negative training sample size is 39891
# positive test sample size is 28
# negative test sample size is 9972
# The accuracy is for KIDNAPPING: 0.732400
# for crime RUNAWAY
# positive training sample size is 91
# negative training sample size is 39909
# positive test sample size is 15
# negative test sample size is 9985
# The accuracy is for RUNAWAY: 0.797600
# for crime DRIVING UNDER THE INFLUENCE
# positive training sample size is 96
# negative training sample size is 39904
# positive test sample size is 30
# negative test sample size is 9970
# The accuracy is for DRIVING UNDER THE INFLUENCE: 0.801700
# for crime SEX OFFENSES FORCIBLE
# positive training sample size is 206
# negative training sample size is 39794
# positive test sample size is 38
# negative test sample size is 9962
# The accuracy is for SEX OFFENSES FORCIBLE: 0.634000
# for crime PROSTITUTION
# positive training sample size is 339
# negative training sample size is 39661
# positive test sample size is 88
# negative test sample size is 9912
# The accuracy is for PROSTITUTION: 0.905800
# for crime DISORDERLY CONDUCT
# positive training sample size is 190
# negative training sample size is 39810
# positive test sample size is 48
# negative test sample size is 9952
# The accuracy is for DISORDERLY CONDUCT: 0.655000
# for crime ARSON
# positive training sample size is 60
# negative training sample size is 39940
# positive test sample size is 18
# negative test sample size is 9982
# The accuracy is for ARSON: 0.816600
# for crime FAMILY OFFENSES
# positive training sample size is 25
# negative training sample size is 39975
# positive test sample size is 2
# negative test sample size is 9998
# The accuracy is for FAMILY OFFENSES: 0.935600
# for crime LIQUOR LAWS
# positive training sample size is 96
# negative training sample size is 39904
# positive test sample size is 19
# negative test sample size is 9981
# The accuracy is for LIQUOR LAWS: 0.732400
# for crime BRIBERY
# positive training sample size is 10
# negative training sample size is 39990
# positive test sample size is 1
# negative test sample size is 9999
# The accuracy is for BRIBERY: 0.998500
# for crime EMBEZZLEMENT
# positive training sample size is 55
# negative training sample size is 39945
# positive test sample size is 15
# negative test sample size is 9985
# The accuracy is for EMBEZZLEMENT: 0.789700
# for crime SUICIDE
# positive training sample size is 31
# negative training sample size is 39969
# positive test sample size is 12
# negative test sample size is 9988
# The accuracy is for SUICIDE: 0.855000
# for crime LOITERING
# positive training sample size is 46
# negative training sample size is 39954
# positive test sample size is 16
# negative test sample size is 9984
# The accuracy is for LOITERING: 0.875600
# for crime SEX OFFENSES NON FORCIBLE
# positive training sample size is 9
# negative training sample size is 39991
# positive test sample size is 3
# negative test sample size is 9997
# The accuracy is for SEX OFFENSES NON FORCIBLE: 0.996600
# for crime EXTORTION
# positive training sample size is 10
# negative training sample size is 39990
# positive test sample size is 2
# negative test sample size is 9998
# The accuracy is for EXTORTION: 0.999800
# for crime GAMBLING
# positive training sample size is 6
# negative training sample size is 39994
# positive test sample size is 0
# negative test sample size is 10000
# The accuracy is for GAMBLING: 1.000000
# for crime BAD CHECKS
# positive training sample size is 19
# negative training sample size is 39981
# positive test sample size is 3
# negative test sample size is 9997
# The accuracy is for BAD CHECKS: 0.988200
# for crime TREA
# positive training sample size is 2
# negative training sample size is 39998
# positive test sample size is 0
# negative test sample size is 10000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-8febea703343> in <module>()
#      33
#      34     gmm_positive = GMM(n_components = 4, covariance_type = 'full' )
# ---> 35     gmm_positive.fit(train1_2d_positive)
#      36     gmm_negative = GMM(n_components = 4, covariance_type = 'full' )
#      37     gmm_negative.fit(train1_2d_negative)
#
# /anaconda/lib/python3.4/site-packages/sklearn/mixture/base.py in fit(self, X, y)
#     188         self
#     189         """
# --> 190         X = _check_X(X, self.n_components)
#     191         self._check_initial_parameters(X)
#     192
#
# /anaconda/lib/python3.4/site-packages/sklearn/mixture/base.py in _check_X(X, n_components, n_features)
#      56         raise ValueError('Expected n_samples >= n_components '
#      57                          'but got n_components = %d, n_samples = %d'
# ---> 58                          % (n_components, X.shape[0]))
#      59     if n_features is not None and X.shape[1] != n_features:
#      60         raise ValueError("Expected the input data X have %d features, "
#
# ValueError: Expected n_samples >= n_components but got n_components = 4, n_samples = 2
